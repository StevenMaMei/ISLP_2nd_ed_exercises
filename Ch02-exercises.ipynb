# %%
import pandas as pd
college_raw_df = pd.read_csv('college.csv')
college_df = college_raw_df.rename({'Unnamed: 0': 'College'}, axis= 1).set_index('College')
college_df
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college_df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
#  Use the pd.plotting.scatter_matrix() function to produce a
# scatterplot matrix of the frst columns [Top10perc, Apps, Enroll].
# Recall that you can reference a list C of columns of a data frame
# A using A[C].

# %%
pd.plotting.scatter_matrix(college_df[["Top10perc", "Apps", "Enroll"]])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
#  Use the boxplot() method of college to produce side-by-side
# boxplots of Outstate versus Private

# %%
college_df["Private"] = college_df["Private"].astype(str) 
college_df.boxplot(column="Outstate", by="Private")
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %% [markdown]
# Create a new qualitative variable, called Elite, by binning the
# Top10perc variable into two groups based on whether or not the
# proportion of students coming from the top 10% of their high
# school classes exceeds 50%.
# Use the value_counts() method of college['Elite'] to see how
# many elite universities there are. Finally, use the boxplot() method
# again to produce side-by-side boxplots of Outstate versus Elite.

# %%
college_df["Elite"]=pd.cut(college_df['Top10perc']/college_df['Enroll'], [0, 0.5, 1], labels = ["No","Yes"])
len(college_df.loc[lambda df: df["Elite"] == "Yes"])
# Out:
# 2

# %%
college_df["Elite"].value_counts()
# Out:
# Elite
# No     775
# Yes      2
# Name: count, dtype: int64

# %%
college_df.boxplot(column="Outstate", by="Elite")
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
#  # Exercise
#  Use the plot.hist() method of college to produce some histograms with difering numbers of bins for a few of the quantitative variables. The command plt.subplots(2, 2) may be useful: it will divide the plot window into four regions so that four
# plots can be made simultaneously. By changing the arguments
# you can divide the screen up in other combinations.

# %%
from matplotlib.pyplot import subplots
fig, axes = subplots(2,2)

college_df.plot.hist(column="Outstate",bins=10, ax=axes[0][0])
college_df.plot.hist(column="Apps",bins=5, ax=axes[0][1])
college_df.plot.hist(column="Expend",bins=15, ax=axes[1][0])
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# This exercise involves the Auto data set studied in the lab. Make sure
# that the missing values have been removed from the data.

# %%
import pandas as pd
auto_df = pd.read_csv('Auto.data', delim_whitespace=True, na_values=["?"]).dropna()

# %% [markdown]
# Which of the predictors are quantitative, and which are qualitative?

# %%
auto_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0  3504.0          12.0    70
# 1    15.0          8         350.0       165.0  3693.0          11.5    70
# 2    18.0          8         318.0       150.0  3436.0          11.0    70
# 3    16.0          8         304.0       150.0  3433.0          12.0    70
# 4    17.0          8         302.0       140.0  3449.0          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0  2790.0          15.6    82
# 393  44.0          4          97.0        52.0  2130.0          24.6    82
# 394  32.0          4         135.0        84.0  2295.0          11.6    82
# 395  28.0          4         120.0        79.0  2625.0          18.6    82
# 396  31.0          4         119.0        82.0  2720.0          19.4    82
#
#      origin                       name
# ...

# %% [markdown]
# Qualitative: year, name, origin
# Quantitative: mpg, cylinders, displacement, horsepower, weight, acceleration

# %% [markdown]
# What is the range of each quantitative predictor? You can answer this using the min() and max() methods in numpy.

# %%
auto_df.drop(columns=["year", "origin"]).describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration
# count    392.000000
# mean      15.541327
# std        2.758864
# min        8.000000
# 25%       13.775000
# 50%       15.500000
# 75%       17.025000
# max       24.800000

# %% [markdown]
# Now remove the 10th through 85th observations. What is the
# range, mean, and standard deviation of each predictor in the
# subset of the data that remains?

# %%
auto_df.drop(auto_df.index[10:85]).drop(columns=["year","origin"]).describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  317.000000  317.000000    317.000000  317.000000   317.000000
# mean    24.374763    5.381703    187.880126  101.003155  2938.854890
# std      7.872565    1.658135    100.169973   36.003208   811.640668
# min     11.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     18.000000    4.000000    101.000000   75.000000  2215.000000
# 50%     23.900000    4.000000    146.000000   90.000000  2795.000000
# 75%     30.500000    6.000000    250.000000  115.000000  3520.000000
# max     46.600000    8.000000    455.000000  230.000000  4997.000000
#
#        acceleration
# count    317.000000
# mean      15.704101
# std        2.719913
# min        8.500000
# 25%       14.000000
# 50%       15.500000
# 75%       17.300000
# max       24.800000

# %% [markdown]
# Using the full data set, investigate the predictors graphically,
# using scatterplots or other tools of your choice. Create some plots
# highlighting the relationships among the predictors. Comment
# on your fndings.

# %%
pd.plotting.scatter_matrix(auto_df.drop(columns=["cylinders","displacement","origin"]))
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='horsepower', ylabel='mpg'>,
#         <Axes: xlabel='weight', ylabel='mpg'>,
#         <Axes: xlabel='acceleration', ylabel='mpg'>,
#         <Axes: xlabel='year', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='horsepower'>,
#         <Axes: xlabel='horsepower', ylabel='horsepower'>,
#         <Axes: xlabel='weight', ylabel='horsepower'>,
#         <Axes: xlabel='acceleration', ylabel='horsepower'>,
#         <Axes: xlabel='year', ylabel='horsepower'>],
#        [<Axes: xlabel='mpg', ylabel='weight'>,
#         <Axes: xlabel='horsepower', ylabel='weight'>,
#         <Axes: xlabel='weight', ylabel='weight'>,
#         <Axes: xlabel='acceleration', ylabel='weight'>,
#         <Axes: xlabel='year', ylabel='weight'>],
#        [<Axes: xlabel='mpg', ylabel='acceleration'>,
#         <Axes: xlabel='horsepower', ylabel='acceleration'>,
#         <Axes: xlabel='weight', ylabel='acceleration'>,
# ...

# %%
auto_df.plot.scatter("horsepower", "year")
# Seems that the most recent the year the less horsepower in cars
# Out:
# <Axes: xlabel='horsepower', ylabel='year'>

# %%
Suppose that we wish to predict gas mileage (mpg) on the basis
of the other variables. Do your plots suggest that any of the
other variables might be useful in predicting mpg? Justify your
answer.

Response//
- It seems that less horsepower implies more mpg, the same goes with the weight

# %% [markdown]
# # Exercise
# This exercise involves the Boston housing data set.

# %%
import pandas as pd
boston_df = pd.read_csv("boston.csv")

# %% [markdown]
# How many rows are in this data set? How many columns? What
# do the rows and columns represent?

# %%
boston_df
# 506 rows and 14 cols
# Seems that the rows are specific neighborhoods or zones within Boston
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio  lstat  medv
# ...

# %% [markdown]
#  Make some pairwise scatterplots of the predictors (columns) in
# this data set. Describe your fndings.

# %%
pd.plotting.scatter_matrix(boston_df)
# Out:
# array([[<Axes: xlabel='Unnamed: 0', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='crim', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='zn', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='indus', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='chas', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='nox', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='rm', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='age', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='dis', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='rad', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='tax', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='ptratio', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='lstat', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='medv', ylabel='Unnamed: 0'>],
#        [<Axes: xlabel='Unnamed: 0', ylabel='crim'>,
#         <Axes: xlabel='crim', ylabel='crim'>,
#         <Axes: xlabel='zn', ylabel='crim'>,
#         <Axes: xlabel='indus', ylabel='crim'>,
# ...

# %% [markdown]
# Are any of the predictors associated with per capita crime rate?
# If so, explain the relationship.

# %%
for col in boston_df.columns:
    boston_df.plot.scatter("crim", col)

# %% [markdown]
# Seems that lstat and medv have some relation

# %% [markdown]
# Do any of the suburbs of Boston appear to have particularly
# high crime rates? Tax rates? Pupil-teacher ratios? Comment on
# the range of each predictor.

# %%
boston_df[["crim","tax","ptratio"]].describe()
# Out:
#              crim         tax     ptratio
# count  506.000000  506.000000  506.000000
# mean     3.613524  408.237154   18.455534
# std      8.601545  168.537116    2.164946
# min      0.006320  187.000000   12.600000
# 25%      0.082045  279.000000   17.400000
# 50%      0.256510  330.000000   19.050000
# 75%      3.677083  666.000000   20.200000
# max     88.976200  711.000000   22.000000

# %% [markdown]
# Crime: Yes, the max is waay higher than the mean + a couple of std
# tax: It doesn't seem there is a high ratio that is significant
# ptratio: Also seems normal

# %% [markdown]
# How many of the suburbs in this data set bound the Charles
# river?

# %%
boston_df[boston_df.chas ==1]["chas"].value_counts()
# 35
# Out:
# chas
# 1    35
# Name: count, dtype: int64

# %% [markdown]
# What is the median pupil-teacher ratio among the towns in this
# data set?

# %%
boston_df["ptratio"].describe()
# 19.050000 50% percentile
# Out:
# count    506.000000
# mean      18.455534
# std        2.164946
# min       12.600000
# 25%       17.400000
# 50%       19.050000
# 75%       20.200000
# max       22.000000
# Name: ptratio, dtype: float64

# %%
boston_df.sort_values(by="medv")
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 398         399  38.35180   0.0  18.10     0  0.693  5.453  100.0  1.4896
# 405         406  67.92080   0.0  18.10     0  0.693  5.683  100.0  1.4254
# 400         401  25.04610   0.0  18.10     0  0.693  5.987  100.0  1.5888
# 399         400   9.91655   0.0  18.10     0  0.693  5.852   77.8  1.5004
# 414         415  45.74610   0.0  18.10     0  0.693  4.519  100.0  1.6582
# ..          ...       ...   ...    ...   ...    ...    ...    ...     ...
# 166         167   2.01019   0.0  19.58     0  0.605  7.929   96.2  2.0459
# 195         196   0.01381  80.0   0.46     0  0.422  7.875   32.0  5.6484
# 283         284   0.01501  90.0   1.21     1  0.401  7.923   24.8  5.8850
# 225         226   0.52693   0.0   6.20     0  0.504  8.725   83.0  2.8944
# 186         187   0.05602   0.0   2.46     0  0.488  7.831   53.6  3.1992
#
#      rad  tax  ptratio  lstat  medv
# 398   24  666     20.2  30.59   5.0
# ...

# %%
boston_df.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...
